-- %%
%defaultDatasource jdbc:h2:file:~/database/socioeco

-- %%
DROP TABLE IF EXISTS Pais;

DROP TABLE IF EXISTS Testagem;
DROP TABLE IF EXISTS Tratamento;
DROP TABLE IF EXISTS Prevencao;
DROP TABLE IF EXISTS Legislacao;



CREATE TABLE Testagem(
    country VARCHAR(60) NOT NULL,
    "Testing approaches used Client-initiated testing and counselling" VARCHAR(100),
    "Testing approaches used Provider-initiated testing and counselling" VARCHAR(100),
    "Testing approaches used Routine antenatal testing" VARCHAR(100),
    "Testing approaches used Community-based testing and counselling" VARCHAR(100),
    "Testing approaches used Home testing" VARCHAR(100),
    "Testing approaches used Lay provider testing" VARCHAR(100),
    "Testing approaches used Self-testing" VARCHAR(100),
    "Testing approaches used Assisted partner notification/index testing" VARCHAR(100),
    "Testing approaches used Other" VARCHAR(100),
    "Testing approaches used Social network-based testing" VARCHAR(100),
    "Period(s) when retesting is done: During pregnancy" VARCHAR(100),
    "Period(s) when retesting is done: At delivery" VARCHAR(100),
    "Period(s) when retesting is done: Post-partum/breastfeeding" VARCHAR(100),
    "Country adopted 2015 WHO guidelines recommendations on HIV testing services" VARCHAR(100),
    "Country has a national policy on HIV self-testing" VARCHAR(100),
    "Self-testing implemented (in countries with a national self-testing policy)" VARCHAR(100),
    "Planned to include self-testing in national policy (countries where not already included)" VARCHAR(100),
    "Assisted HIV partner notification included in national policy" VARCHAR(100),
    "Planned to include assisted HIV partner notification in national policy (countries where not already included)" VARCHAR(100),
    "Policy on HIV testing provision free to all, free to some or at a cost" VARCHAR(100),
    "Law specifying HIV testing solely performed based on voluntary and informed consent" VARCHAR(100),
    "Law specifying HIV testing is mandatory before marriage" VARCHAR(100),
    "Law specifying HIV testing is mandatory to obtain a work or residence permit" VARCHAR(100),
    "Law specifying HIV testing is mandatory for certain groups: National authorities" VARCHAR(100),
    "Law specifying HIV testing is mandatory for certain groups: Civil society" VARCHAR(100),
    "Country has a national policy/ strategy on linking HIV testing and counselling and enrolment in care" VARCHAR(100),
    "Country adapted 2016 WHO consolidated guidelines recommendations: adult antiretroviral therapy" VARCHAR(100),
    "National STI treatment guidelines or recommendations" VARCHAR(100),
    "National strategy/action plan for STI prevention and control" VARCHAR(100),
    "Gonococcal antimicrobial resistance monitoring conducted" VARCHAR(100),
    "National definition for congenital syphilis includes stillbirths" VARCHAR(100),
    "National strategy/policy guiding AIDS response" VARCHAR(100),
    "National HIV strategy/policy reviewed in last 2 years" VARCHAR(100),
    "National AIDS strategy/policy includes gender-transformative interventions" VARCHAR(100),
    "National AIDS strategy/policy includes dedicated budget for gender transformative interventions" VARCHAR(100),
    "Completeness of death reporting to civil registration and vital statistics system" VARCHAR(100),
    "Deaths must be reported using a standard death report form that includes cause of death" VARCHAR(100),
    "Individual-level data on reported deaths can be reported directly to the country's national HIV case reporting system" VARCHAR(100),
    "Individual-level data on reported deaths can be linked to the country's national HIV case reporting system" VARCHAR(100),
    "Country adapted 2018 WHO consolidated guidelines on ARV use for treating and preventing HIV infection" VARCHAR(100),
    "Country adopted WHO 2017 recommendation on rapid initiation on ART" VARCHAR(100),
    "Possible to start ART on the same day as HIV diagnosis" VARCHAR(100),
    "Country adopted WHO 2017 recommendation to offer interventions for advanced HIV disease" VARCHAR(100),
    "Implementation status of recommended interventions for advanced HIV disease" VARCHAR(100),
    "Country has a policy on retesting HIV-negative women during pregnancy/delivery and/or the post-partum/breastfeeding period" VARCHAR(100),
    "Travel-related mandatory HIV testing and HIV-related restrictions on entry, stay and residence (by group)" VARCHAR(100),
    "Travel-related mandatory HIV testing and HIV-related restrictions on entry, stay and residence: HIV testing required for work permit" VARCHAR(100),
    "Travel-related mandatory HIV testing and HIV-related restrictions on entry, stay and residence: HIV testing required for study permit" VARCHAR(100),
    PRIMARY KEY(country)
) AS SELECT
    Country ,
    "Testing approaches used Client-initiated testing and counselling" ,
    "Testing approaches used Provider-initiated testing and counselling" ,
    "Testing approaches used Routine antenatal testing" ,
    "Testing approaches used Community-based testing and counselling" ,
    "Testing approaches used Home testing" ,
    "Testing approaches used Lay provider testing" ,
    "Testing approaches used Self-testing" ,
    "Testing approaches used Assisted partner notification/index testing" ,
    "Testing approaches used Other" ,
    "Testing approaches used Social network-based testing" ,
    "Period(s) when retesting is done: During pregnancy" ,
    "Period(s) when retesting is done: At delivery" ,
    "Period(s) when retesting is done: Post-partum/breastfeeding" ,
    "Country adopted 2015 WHO guidelines recommendations on HIV testing services" ,
    "Country has a national policy on HIV self-testing" ,
    "Self-testing implemented (in countries with a national self-testing policy)" ,
    "Planned to include self-testing in national policy (countries where not already included)" ,
    "Assisted HIV partner notification included in national policy" ,
    "Planned to include assisted HIV partner notification in national policy (countries where not already included)" ,
    "Policy on HIV testing provision free to all, free to some or at a cost" ,
    "Law specifying HIV testing solely performed based on voluntary and informed consent" ,
    "Law specifying HIV testing is mandatory before marriage" ,
    "Law specifying HIV testing is mandatory to obtain a work or residence permit" ,
    "Law specifying HIV testing is mandatory for certain groups: National authorities" ,
    "Law specifying HIV testing is mandatory for certain groups: Civil society" ,
    "Country has a national policy/ strategy on linking HIV testing and counselling and enrolment in care" ,
    "Country adapted 2016 WHO consolidated guidelines recommendations: adult antiretroviral therapy" ,
    "National STI treatment guidelines or recommendations" ,
    "National strategy/action plan for STI prevention and control" ,
    "Gonococcal antimicrobial resistance monitoring conducted" ,
    "National definition for congenital syphilis includes stillbirths" ,
    "National strategy/policy guiding AIDS response" ,
    "National HIV strategy/policy reviewed in last 2 years" ,
    "National AIDS strategy/policy includes gender-transformative interventions" ,
    "National AIDS strategy/policy includes dedicated budget for gender transformative interventions" ,
    "Completeness of death reporting to civil registration and vital statistics system" ,
    "Deaths must be reported using a standard death report form that includes cause of death" ,
    "Individual-level data on reported deaths can be reported directly to the country's national HIV case reporting system" ,
    "Individual-level data on reported deaths can be linked to the country's national HIV case reporting system" ,
    "Country adapted 2018 WHO consolidated guidelines on ARV use for treating and preventing HIV infection" ,
    "Country adopted WHO 2017 recommendation on rapid initiation on ART" ,
    "Possible to start ART on the same day as HIV diagnosis" ,
    "Country adopted WHO 2017 recommendation to offer interventions for advanced HIV disease" ,
    "Implementation status of recommended interventions for advanced HIV disease" ,
    "Country has a policy on retesting HIV-negative women during pregnancy/delivery and/or the post-partum/breastfeeding period" ,
    "Travel-related mandatory HIV testing and HIV-related restrictions on entry, stay and residence (by group)" ,
    "Travel-related mandatory HIV testing and HIV-related restrictions on entry, stay and residence: HIV testing required for work permit" ,
    "Travel-related mandatory HIV testing and HIV-related restrictions on entry, stay and residence: HIV testing required for study permit" 
FROM CSVREAD('../data/Filtered Data/testagem.csv');

CREATE TABLE Tratamento(
    country VARCHAR(60) NOT NULL,
    "National guidelines recommend ART for All people living with HIV with active TB" VARCHAR(100),
    "National guidelines recommend ART for All people living with HIV with hepatitis B and severe liver disease" VARCHAR(100),
    "National guidelines recommend ART for The HIV-positive partner in serodiscordant couples" VARCHAR(100),
    "National guidelines recommend ART for All people living with HIV identified as being in key populations" VARCHAR(100),
    "Nurse-initiated ART allowed for Non-pregnant adults" VARCHAR(100),
    "Nurse-initiated ART allowed for Pregnant women" VARCHAR(100),
    "Nurse-initiated ART allowed for Adolescents (10-19 years old)" VARCHAR(100),
    "Nurse-initiated ART allowed for Children younger than 10 years old" VARCHAR(100),
    "Nurse-initiated ART allowed for None of the above" VARCHAR(100),
    "ART provided in TB clinics" VARCHAR(100),
    "ART providers provide TB treatment in ART settings" VARCHAR(100),
    "MNCH services providers provide ART in MNCH clinics" VARCHAR(100),
    "Nutrition assessment, counselling and support to malnourished people living with HIV" VARCHAR(100),
    "ART in settings providing OST" VARCHAR(100),
    "ART provided in primary health care settings" VARCHAR(100),
    "Patient support" VARCHAR(100),
    "ART delivered in the community" VARCHAR(100),
    "Cardiovascular disease screening/management by ART providers" VARCHAR(100),
    "Mental health screening/treatment by ART providers" VARCHAR(100),
    "Country has a national policy/ strategy on linking HIV testing and counselling and enrolment in care" VARCHAR(100),
    "Country adapted 2016 WHO consolidated guidelines recommendations: adult antiretroviral therapy" VARCHAR(100),
    "Country adapted 2016 WHO consolidated guidelines recommendations: PMTCT" VARCHAR(100),
    "Country adapted 2016 WHO consolidated guidelines recommendations: pediatric antiretroviral therapy" VARCHAR(100),
    "Country adapted 2016 WHO consolidated guidelines recommendations: operational/service delivery" VARCHAR(100),
    "Recommended ART CD4 initiation threshold in adults and adolescents" VARCHAR(100),
    "Implementation status of recommended ART CD4 initiation threshold" VARCHAR(100),
    "Planned adoption of treat all recommendation (countries where not already adopted)" VARCHAR(100),
    "Planned year for adoption of treat all recommendation (countries where not already adopted)" VARCHAR(100),
    "Point-of-care CD4 technology used" VARCHAR(100),
    "Percentage of primary healthcare facilitates with access to CD4 cell count testing (nearby or referral)" VARCHAR(100),
    "Policy promoting community ART delivery" VARCHAR(100),
    "ART provided in community settings for people stable on ART" VARCHAR(100),
    "Implementation of ART provision in community settings for people stable on ART" VARCHAR(100),
    "Policy on prioritization of people with advanced HIV disease" VARCHAR(100),
    "Policy on frequency of clinic visits for people stable on ART" VARCHAR(100),
    "Frequency of clinic visits for people stable on ART in policy" VARCHAR(100),
    "Policy on frequency of ART pick-up for people stable on ART" VARCHAR(100),
    "Frequency of ART pick-up for people stable on ART in policy" VARCHAR(100),
    "Country has a national plan for eliminating HIV MTCT" VARCHAR(100),
    "Recommended PMTCT regimen" VARCHAR(100),
    "Recommended first-line ART regimen for pregnant and breastfeeding women living with HIV" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing with SRH" VARCHAR(100),
    "Health facilities delivering integrated services: HIV treatment and care with SRH" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing with TB services" VARCHAR(100),
    "Health facilities delivering integrated services: TB screening in HIV services" VARCHAR(100),
    "Health facilities delivering integrated services: ART and TB treatment" VARCHAR(100),
    "Health facilities delivering integrated services: HIV and hepatitis C treatment" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing and chronic NCDs" VARCHAR(100),
    "Health facilities delivering integrated services: ART and chronic NCDs" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing and general outpatient care" VARCHAR(100),
    "Health facilities delivering integrated services: ART and general outpatient care" VARCHAR(100),
    "Health facilities delivering integrated services: Violence screening and mitigation with HIV services" VARCHAR(100),
    "Health facilities delivering integrated services: HIV testing and counselling with cervical cancer screening and treatment" VARCHAR(100),
    "Health facilities delivering integrated services: Cervical cancer screening with HIV services" VARCHAR(100),
    "Health facilities delivering integrated services: PMTCT with antenatal care / maternal and child health" VARCHAR(100),
    "Health facilities delivering integrated services: HIV treatment and care with nutrition support" VARCHAR(100),
    "Health facilities delivering integrated services: HIV testing with child health services" VARCHAR(100),
    "Health facilities delivering integrated services: HIV treatment and care with child health services" VARCHAR(100),
    "Health facilities delivering integrated services: HIV and harm reduction services" VARCHAR(100),
    "Country adapted 2018 WHO consolidated guidelines on ARV use for treating and preventing HIV infection" VARCHAR(100),
    "Country adopted WHO 2017 recommendation on rapid initiation on ART" VARCHAR(100),
    "Possible to start ART on the same day as HIV diagnosis" VARCHAR(100),
    "Country adopted WHO 2017 recommendation to offer interventions for advanced HIV disease" VARCHAR(100),
    "Implementation status of recommended interventions for advanced HIV disease" VARCHAR(100),
    "Implementation status of same day start of ART" VARCHAR(100),
    "Availability of CD4 testing for immunological staging" VARCHAR(100),
    "Percentage of clients with access to CD4 testing for immunological staging" VARCHAR(100),
    PRIMARY KEY(country)
) AS SELECT
    country ,
    "National guidelines recommend ART for All people living with HIV with active TB" ,
    "National guidelines recommend ART for All people living with HIV with hepatitis B and severe liver disease" ,
    "National guidelines recommend ART for The HIV-positive partner in serodiscordant couples" ,
    "National guidelines recommend ART for All people living with HIV identified as being in key populations" ,
    "Nurse-initiated ART allowed for Non-pregnant adults" ,
    "Nurse-initiated ART allowed for Pregnant women" ,
    "Nurse-initiated ART allowed for Adolescents (10-19 years old)" ,
    "Nurse-initiated ART allowed for Children younger than 10 years old" ,
    "Nurse-initiated ART allowed for None of the above" ,
    "ART provided in TB clinics" ,
    "ART providers provide TB treatment in ART settings" ,
    "MNCH services providers provide ART in MNCH clinics" ,
    "Nutrition assessment, counselling and support to malnourished people living with HIV" ,
    "ART in settings providing OST" ,
    "ART provided in primary health care settings" ,
    "Patient support" ,
    "ART delivered in the community" ,
    "Cardiovascular disease screening/management by ART providers" ,
    "Mental health screening/treatment by ART providers" ,
    "Country has a national policy/ strategy on linking HIV testing and counselling and enrolment in care" ,
    "Country adapted 2016 WHO consolidated guidelines recommendations: adult antiretroviral therapy" ,
    "Country adapted 2016 WHO consolidated guidelines recommendations: PMTCT" ,
    "Country adapted 2016 WHO consolidated guidelines recommendations: pediatric antiretroviral therapy" ,
    "Country adapted 2016 WHO consolidated guidelines recommendations: operational/service delivery" ,
    "Recommended ART CD4 initiation threshold in adults and adolescents" ,
    "Implementation status of recommended ART CD4 initiation threshold" ,
    "Planned adoption of treat all recommendation (countries where not already adopted)" ,
    "Planned year for adoption of treat all recommendation (countries where not already adopted)" ,
    "Point-of-care CD4 technology used" ,
    "Percentage of primary healthcare facilitates with access to CD4 cell count testing (nearby or referral)" ,
    "Policy promoting community ART delivery" ,
    "ART provided in community settings for people stable on ART" ,
    "Implementation of ART provision in community settings for people stable on ART" ,
    "Policy on prioritization of people with advanced HIV disease" ,
    "Policy on frequency of clinic visits for people stable on ART" ,
    "Frequency of clinic visits for people stable on ART in policy" ,
    "Policy on frequency of ART pick-up for people stable on ART" ,
    "Frequency of ART pick-up for people stable on ART in policy" ,
    "Country has a national plan for eliminating HIV MTCT" ,
    "Recommended PMTCT regimen" ,
    "Recommended first-line ART regimen for pregnant and breastfeeding women living with HIV" ,
    "Health facilities delivering integrated services: HIV counselling and testing with SRH" ,
    "Health facilities delivering integrated services: HIV treatment and care with SRH" ,
    "Health facilities delivering integrated services: HIV counselling and testing with TB services" ,
    "Health facilities delivering integrated services: TB screening in HIV services" ,
    "Health facilities delivering integrated services: ART and TB treatment" ,
    "Health facilities delivering integrated services: HIV and hepatitis C treatment" ,
    "Health facilities delivering integrated services: HIV counselling and testing and chronic NCDs" ,
    "Health facilities delivering integrated services: ART and chronic NCDs" ,
    "Health facilities delivering integrated services: HIV counselling and testing and general outpatient care" ,
    "Health facilities delivering integrated services: ART and general outpatient care" ,
    "Health facilities delivering integrated services: Violence screening and mitigation with HIV services" ,
    "Health facilities delivering integrated services: HIV testing and counselling with cervical cancer screening and treatment" ,
    "Health facilities delivering integrated services: Cervical cancer screening with HIV services" ,
    "Health facilities delivering integrated services: PMTCT with antenatal care / maternal and child health" ,
    "Health facilities delivering integrated services: HIV treatment and care with nutrition support" ,
    "Health facilities delivering integrated services: HIV testing with child health services" ,
    "Health facilities delivering integrated services: HIV treatment and care with child health services" ,
    "Health facilities delivering integrated services: HIV and harm reduction services" ,
    "Country adapted 2018 WHO consolidated guidelines on ARV use for treating and preventing HIV infection" ,
    "Country adopted WHO 2017 recommendation on rapid initiation on ART" ,
    "Possible to start ART on the same day as HIV diagnosis" ,
    "Country adopted WHO 2017 recommendation to offer interventions for advanced HIV disease" ,
    "Implementation status of recommended interventions for advanced HIV disease" ,
    "Implementation status of same day start of ART" ,
    "Availability of CD4 testing for immunological staging" ,
    "Percentage of clients with access to CD4 testing for immunological staging" 
FROM CSVREAD('../data/Filtered Data/tratamento.csv');

CREATE TABLE Prevencao(
    country VARCHAR(60) NOT NULL,
    "Condom strategy/plan addresses needs and targeted condom programming for General public" VARCHAR(100),
    "Condom strategy/plan addresses needs and targeted condom programming for Men who have sex with men" VARCHAR(100),
    "Condom strategy/plan addresses needs and targeted condom programming for People living with HIV" VARCHAR(100),
    "Condom strategy/plan addresses needs and targeted condom programming for People who inject drugs" VARCHAR(100),
    "Condom strategy/plan addresses needs and targeted condom programming for People with STIs" VARCHAR(100),
    "Condom strategy/plan addresses needs and targeted condom programming for Prisoners" VARCHAR(100),
    "Condom strategy/plan addresses needs and targeted condom programming for Sex workers (male and female)" VARCHAR(100),
    "Condom strategy/plan addresses needs and targeted condom programming for Young people" VARCHAR(100),
    "Condom strategy/plan includes Free distribution to key populations" VARCHAR(100),
    "Condom strategy/plan includes Subsidized condom marketing" VARCHAR(100),
    "Condom strategy/plan includes Private sector sales" VARCHAR(100),
    "Condom strategy/plan includes Condom promotion through mass media" VARCHAR(100),
    "Condom strategy/plan includes Condom promotion in (secondary) schools" VARCHAR(100),
    "Condom strategy/plan includes Condom distribution in (secondary) schools" VARCHAR(100),
    "Condom strategy/plan includes Condom promotion through outreach to communities with high HIV incidence" VARCHAR(100),
    "Coinfection policies: IPT or latent TB infection prophylaxis for people living with HIV" VARCHAR(100),
    "Coinfection policies: Intensified TB case finding among people living with HIV" VARCHAR(100),
    "Coinfection policies: TB infection control in HIV health-care settings" VARCHAR(100),
    "Coinfection policies: Co-trimoxazole prophylaxis" VARCHAR(100),
    "Coinfection policies: Hepatitis B screening and management in ART clinics" VARCHAR(100),
    "Coinfection policies: Hepatitis C screening and management in ART clinics" VARCHAR(100),
    "Coinfection policies: Hepatitis B vaccination provided at ART clinics" VARCHAR(100),
    "Coinfection policies: Hepatitis C treatment provided in ART clinics" VARCHAR(100),
    "National AIDS strategy/policy addresses Adolescent key populations" VARCHAR(100),
    "National AIDS strategy/policy addresses Men who have sex with men" VARCHAR(100),
    "National AIDS strategy/policy addresses People in prisons and other closed settings" VARCHAR(100),
    "National AIDS strategy/policy addresses People who inject drugs" VARCHAR(100),
    "National AIDS strategy/policy addresses Sex workers (male and female)" VARCHAR(100),
    "National AIDS strategy/policy addresses Transgender people" VARCHAR(100),
    "National AIDS strategy/policy addresses Non-displaced people affected by emergencies" VARCHAR(100),
    "National AIDS strategy/policy addresses Refugees" VARCHAR(100),
    "National AIDS strategy/policy addresses Internally displaced people" VARCHAR(100),
    "National AIDS strategy/policy addresses Migrants and asylum-seekers" VARCHAR(100),
    "National AIDS strategy/policy Includes plans/activities addressing needs of key populations" VARCHAR(100),
    "National AIDS strategy/policy Includes plans/activities addressing needs of young women and girls" VARCHAR(100),
    "National AIDS strategy/policy Draws on most recent evidence" VARCHAR(100),
    "National AIDS strategy/policy Integrated inputs from a multisectoral process" VARCHAR(100),
    "Policy in place for provider-initiated condom promotion and distribution for all people of reproductive age visiting a health facility" VARCHAR(100),
    "Policy in place for provider-initiated condom promotion and distribution for all key populations and other people at higher risk of HIV infection" VARCHAR(100),
    "Policy in place for provider-initiated condom promotion and distribution for all young people who are sexually active" VARCHAR(100),
    "Policy in place for provider-initiated condom promotion and distribution for all people accessing HIV testing services" VARCHAR(100),
    "Policy in place for provider-initiated condom promotion and distribution for all people accessing hormonal or other methods of contraception" VARCHAR(100),
    "Policy in place for provider-initiated condom promotion and distribution for all serodiscordant couples" VARCHAR(100),
    "No policy in place for provider-initiated condom promotion and distribution in place" VARCHAR(100),
    "National condom strategy/plan" VARCHAR(100),
    "National condom needs have been estimated" VARCHAR(100),
    "Prosecution/punishment of individuals for carrying condoms" VARCHAR(100),
    "Age restrictions for accessing condoms" VARCHAR(100),
    "Restrictions on condom distribution in public places" VARCHAR(100),
    "National condom stock-outs in the past 12 months" VARCHAR(100),
    "Local condom stock-outs in the past 12 months" VARCHAR(100),
    "Number of male condoms distributed in the previous calendar year: total" INTEGER,
    "Number of male condoms distributed in the previous calendar year: public providers" INTEGER,
    "Number of female condoms distributed in the previous calendar year: total" INTEGER,
    "Number of female condoms distributed in the previous calendar year: public providers" INTEGER,
    "National STI treatment guidelines or recommendations" VARCHAR(100),
    "National strategy/action plan for STI prevention and control" VARCHAR(100),
    PRIMARY KEY(country)
) AS SELECT
    country,
    "Condom strategy/plan addresses needs and targeted condom programming for General public" ,
    "Condom strategy/plan addresses needs and targeted condom programming for Men who have sex with men" ,
    "Condom strategy/plan addresses needs and targeted condom programming for People living with HIV" ,
    "Condom strategy/plan addresses needs and targeted condom programming for People who inject drugs" ,
    "Condom strategy/plan addresses needs and targeted condom programming for People with STIs" ,
    "Condom strategy/plan addresses needs and targeted condom programming for Prisoners" ,
    "Condom strategy/plan addresses needs and targeted condom programming for Sex workers (male and female)" ,
    "Condom strategy/plan addresses needs and targeted condom programming for Young people" ,
    "Condom strategy/plan includes Free distribution to key populations" ,
    "Condom strategy/plan includes Subsidized condom marketing" ,
    "Condom strategy/plan includes Private sector sales" ,
    "Condom strategy/plan includes Condom promotion through mass media" ,
    "Condom strategy/plan includes Condom promotion in (secondary) schools" ,
    "Condom strategy/plan includes Condom distribution in (secondary) schools" ,
    "Condom strategy/plan includes Condom promotion through outreach to communities with high HIV incidence" ,
    "Coinfection policies: IPT or latent TB infection prophylaxis for people living with HIV" ,
    "Coinfection policies: Intensified TB case finding among people living with HIV" ,
    "Coinfection policies: TB infection control in HIV health-care settings" ,
    "Coinfection policies: Co-trimoxazole prophylaxis" ,
    "Coinfection policies: Hepatitis B screening and management in ART clinics" ,
    "Coinfection policies: Hepatitis C screening and management in ART clinics" ,
    "Coinfection policies: Hepatitis B vaccination provided at ART clinics" ,
    "Coinfection policies: Hepatitis C treatment provided in ART clinics" ,
    "National AIDS strategy/policy addresses Adolescent key populations" ,
    "National AIDS strategy/policy addresses Men who have sex with men" ,
    "National AIDS strategy/policy addresses People in prisons and other closed settings" ,
    "National AIDS strategy/policy addresses People who inject drugs" ,
    "National AIDS strategy/policy addresses Sex workers (male and female)" ,
    "National AIDS strategy/policy addresses Transgender people" ,
    "National AIDS strategy/policy addresses Non-displaced people affected by emergencies" ,
    "National AIDS strategy/policy addresses Refugees" ,
    "National AIDS strategy/policy addresses Internally displaced people" ,
    "National AIDS strategy/policy addresses Migrants and asylum-seekers" ,
    "National AIDS strategy/policy Includes plans/activities addressing needs of key populations" ,
    "National AIDS strategy/policy Includes plans/activities addressing needs of young women and girls" ,
    "National AIDS strategy/policy Draws on most recent evidence" ,
    "National AIDS strategy/policy Integrated inputs from a multisectoral process" ,
    "Policy in place for provider-initiated condom promotion and distribution for all people of reproductive age visiting a health facility" ,
    "Policy in place for provider-initiated condom promotion and distribution for all key populations and other people at higher risk of HIV infection" ,
    "Policy in place for provider-initiated condom promotion and distribution for all young people who are sexually active" ,
    "Policy in place for provider-initiated condom promotion and distribution for all people accessing HIV testing services" ,
    "Policy in place for provider-initiated condom promotion and distribution for all people accessing hormonal or other methods of contraception" ,
    "Policy in place for provider-initiated condom promotion and distribution for all serodiscordant couples" ,
    "No policy in place for provider-initiated condom promotion and distribution in place" ,
    "National condom strategy/plan" ,
    "National condom needs have been estimated" ,
    "Prosecution/punishment of individuals for carrying condoms" ,
    "Age restrictions for accessing condoms" ,
    "Restrictions on condom distribution in public places" ,
    "National condom stock-outs in the past 12 months" ,
    "Local condom stock-outs in the past 12 months" ,
    "Number of male condoms distributed in the previous calendar year: total" ,
    "Number of male condoms distributed in the previous calendar year: public providers" ,
    "Number of female condoms distributed in the previous calendar year: total" ,
    "Number of female condoms distributed in the previous calendar year: public providers" ,
    "National STI treatment guidelines or recommendations" ,
    "National strategy/action plan for STI prevention and control" 
FROM CSVREAD('../data/Filtered Data/prevencao.csv');

CREATE TABLE Legislacao(
    country VARCHAR(60) NOT NULL,
    "Country adopted 2015 WHO guidelines recommendations on HIV testing services" VARCHAR(100),
    "Country has a national policy on HIV self-testing" VARCHAR(100),
    "Law specifying HIV testing solely performed based on voluntary and informed consent" VARCHAR(100),
    "Law specifying HIV testing is mandatory before marriage" VARCHAR(100),
    "Law specifying HIV testing is mandatory to obtain a work or residence permit" VARCHAR(100),
    "Law specifying HIV testing is mandatory for certain groups: National authorities" VARCHAR(100),
    "Law specifying HIV testing is mandatory for certain groups: Civil society" VARCHAR(100),
    "Criminalization of vertical transmission of HIV" VARCHAR(100),
    "Policies requiring healthcare settings to provide timely and quality healthcare regardless of any grounds for national authorities" VARCHAR(100),
    "Policies requiring healthcare settings to provide timely and quality healthcare regardless of any grounds for the civil society" VARCHAR(100),
    "Interventions targeting healthcare workers on human rights and gender-based violence" VARCHAR(100),
    "Laws criminalizing transmission of, non-disclosure of or exposure to HIV transmission" VARCHAR(100),
    "Laws restricting entry, stay and residence of people living with HIV" VARCHAR(100),
    "Laws requiring parental consent for adolescents to access sexual and reproductive health services" VARCHAR(100),
    "Laws requiring parental consent for adolescents to access HIV testing" VARCHAR(100),
    "Laws requiring parental consent for adolescents to access HIV treatment" VARCHAR(100),
    "Laws requiring spousal consent for married women to access sexual and reproductive health services" VARCHAR(100),
    "Laws requiring spousal consent for married women to access HIV testing" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing with SRH" VARCHAR(100),
    "Health facilities delivering integrated services: HIV treatment and care with SRH" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing with TB services" VARCHAR(100),
    "Health facilities delivering integrated services: TB screening in HIV services" VARCHAR(100),
    "Health facilities delivering integrated services: ART and TB treatment" VARCHAR(100),
    "Health facilities delivering integrated services: HIV and hepatitis C treatment" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing and chronic NCDs" VARCHAR(100),
    "Health facilities delivering integrated services: ART and chronic NCDs" VARCHAR(100),
    "Health facilities delivering integrated services: HIV counselling and testing and general outpatient care" VARCHAR(100),
    "Health facilities delivering integrated services: ART and general outpatient care" VARCHAR(100),
    "Health facilities delivering integrated services: Violence screening and mitigation with HIV services" VARCHAR(100),
    "Health facilities delivering integrated services: HIV testing and counselling with cervical cancer screening and treatment" VARCHAR(100),
    "Health facilities delivering integrated services: Cervical cancer screening with HIV services" VARCHAR(100),
    "Health facilities delivering integrated services: PMTCT with antenatal care / maternal and child health" VARCHAR(100),
    "Health facilities delivering integrated services: HIV treatment and care with nutrition support" VARCHAR(100),
    "Health facilities delivering integrated services: HIV testing with child health services" VARCHAR(100),
    "Health facilities delivering integrated services: HIV treatment and care with child health services" VARCHAR(100),
    "Health facilities delivering integrated services: HIV and harm reduction services" VARCHAR(100),
    "National strategy/policy guiding AIDS response" VARCHAR(100),
    "National HIV strategy/policy reviewed in last 2 years" VARCHAR(100),
    "National AIDS strategy/policy includes gender-transformative interventions" VARCHAR(100),
    "National AIDS strategy/policy includes dedicated budget for gender transformative interventions" VARCHAR(100),
    "Deaths must be reported using a standard death report form that includes cause of death" VARCHAR(100),
    "Individual-level data on reported deaths can be reported directly to the country's national HIV case reporting system" VARCHAR(100),
    "Individual-level data on reported deaths can be linked to the country's national HIV case reporting system" VARCHAR(100),
    "Country adapted 2018 WHO consolidated guidelines on ARV use for treating and preventing HIV infection" VARCHAR(100),
    "Country adopted WHO 2017 recommendation on rapid initiation on ART" VARCHAR(100),
    "Possible to start ART on the same day as HIV diagnosis" VARCHAR(100),
    "Country adopted WHO 2017 recommendation to offer interventions for advanced HIV disease" VARCHAR(100),
    "Implementation status of recommended interventions for advanced HIV disease" VARCHAR(100),
    "Country has a policy on retesting HIV-negative women during pregnancy/delivery and/or the post-partum/breastfeeding period" VARCHAR(100),
    "Laws requiring parental consent for adolescents to access contraceptives, including condoms" VARCHAR(100),
    "Process exists to deem adolescents mature to access contraceptives without parental consent" VARCHAR(100),
    "Process exists to deem adolescents mature to access HIV testing without parental consent" VARCHAR(100),
    "Process exists to deem adolescents mature to access HIV treatment without parental consent" VARCHAR(100),
    "Percentage of clients with access to CD4 testing for immunological staging" VARCHAR(100),
    PRIMARY KEY(country)
) AS SELECT
    country,
    "Country adopted 2015 WHO guidelines recommendations on HIV testing services" ,
    "Country has a national policy on HIV self-testing" ,
    "Law specifying HIV testing solely performed based on voluntary and informed consent" ,
    "Law specifying HIV testing is mandatory before marriage" ,
    "Law specifying HIV testing is mandatory to obtain a work or residence permit" ,
    "Law specifying HIV testing is mandatory for certain groups: National authorities" ,
    "Law specifying HIV testing is mandatory for certain groups: Civil society" ,
    "Criminalization of vertical transmission of HIV" ,
    "Policies requiring healthcare settings to provide timely and quality healthcare regardless of any grounds for national authorities" ,
    "Policies requiring healthcare settings to provide timely and quality healthcare regardless of any grounds for the civil society" ,
    "Interventions targeting healthcare workers on human rights and gender-based violence" ,
    "Laws criminalizing transmission of, non-disclosure of or exposure to HIV transmission" ,
    "Laws restricting entry, stay and residence of people living with HIV" ,
    "Laws requiring parental consent for adolescents to access sexual and reproductive health services" ,
    "Laws requiring parental consent for adolescents to access HIV testing" ,
    "Laws requiring parental consent for adolescents to access HIV treatment" ,
    "Laws requiring spousal consent for married women to access sexual and reproductive health services" ,
    "Laws requiring spousal consent for married women to access HIV testing" ,
    "Health facilities delivering integrated services: HIV counselling and testing with SRH" ,
    "Health facilities delivering integrated services: HIV treatment and care with SRH" ,
    "Health facilities delivering integrated services: HIV counselling and testing with TB services" ,
    "Health facilities delivering integrated services: TB screening in HIV services" ,
    "Health facilities delivering integrated services: ART and TB treatment" ,
    "Health facilities delivering integrated services: HIV and hepatitis C treatment" ,
    "Health facilities delivering integrated services: HIV counselling and testing and chronic NCDs" ,
    "Health facilities delivering integrated services: ART and chronic NCDs" ,
    "Health facilities delivering integrated services: HIV counselling and testing and general outpatient care" ,
    "Health facilities delivering integrated services: ART and general outpatient care" ,
    "Health facilities delivering integrated services: Violence screening and mitigation with HIV services" ,
    "Health facilities delivering integrated services: HIV testing and counselling with cervical cancer screening and treatment" ,
    "Health facilities delivering integrated services: Cervical cancer screening with HIV services" ,
    "Health facilities delivering integrated services: PMTCT with antenatal care / maternal and child health" ,
    "Health facilities delivering integrated services: HIV treatment and care with nutrition support" ,
    "Health facilities delivering integrated services: HIV testing with child health services" ,
    "Health facilities delivering integrated services: HIV treatment and care with child health services" ,
    "Health facilities delivering integrated services: HIV and harm reduction services" ,
    "National strategy/policy guiding AIDS response" ,
    "National HIV strategy/policy reviewed in last 2 years" ,
    "National AIDS strategy/policy includes gender-transformative interventions" ,
    "National AIDS strategy/policy includes dedicated budget for gender transformative interventions" ,
    "Deaths must be reported using a standard death report form that includes cause of death" ,
    "Individual-level data on reported deaths can be reported directly to the country's national HIV case reporting system" ,
    "Individual-level data on reported deaths can be linked to the country's national HIV case reporting system" ,
    "Country adapted 2018 WHO consolidated guidelines on ARV use for treating and preventing HIV infection" ,
    "Country adopted WHO 2017 recommendation on rapid initiation on ART" ,
    "Possible to start ART on the same day as HIV diagnosis" ,
    "Country adopted WHO 2017 recommendation to offer interventions for advanced HIV disease" ,
    "Implementation status of recommended interventions for advanced HIV disease" ,
    "Country has a policy on retesting HIV-negative women during pregnancy/delivery and/or the post-partum/breastfeeding period" ,
    "Laws requiring parental consent for adolescents to access contraceptives, including condoms" ,
    "Process exists to deem adolescents mature to access contraceptives without parental consent" ,
    "Process exists to deem adolescents mature to access HIV testing without parental consent" ,
    "Process exists to deem adolescents mature to access HIV treatment without parental consent" ,
    "Percentage of clients with access to CD4 testing for immunological staging"
FROM CSVREAD('../data/Filtered Data/legislacao.csv');


CREATE TABLE Pais (
  nome VARCHAR(60),            -- eliminar ambiguidade!
  sigla VARCHAR(3) NOT NULL,
  regiao VARCHAR(30),
  classificacaoRenda VARCHAR(30),
  Gini INTEGER,
  PIBperCapita INTEGER,
  IDH INTEGER,
  populacao INTEGER,
  PRIMARY KEY(sigla)
) AS SELECT
    country,
    label,
    region,
    wb_class,
    gini,
    gdbPPPperCapita,
    hdi,
    populationTotal
FROM CSVREAD('../data/Filtered Data/countries.csv');

-- %%
SELECT Pr.country, 
    CAST(Pr."Number of male condoms distributed in the previous calendar year: total" AS FLOAT) / Pa.populacao  AS "Número de camisinhas masculinas por habitante", 
    CAST(Pr."Number of female condoms distributed in the previous calendar year: total" AS FLOAT) / Pa.populacao  AS "Número de camisinhas femininas por habitante",  
    CAST(Pr."Number of male condoms distributed in the previous calendar year: total" + Pr."Number of female condoms distributed in the previous calendar year: total" AS FLOAT) / Pa.populacao  AS "Número de camisinhas por habitante",
    Pr."National condom strategy/plan",
    Pr."Prosecution/punishment of individuals for carrying condoms"
FROM Prevencao Pr, Pais Pa WHERE Pr.country = Pa.nome ;



DROP VIEW AgrupadoPorRegiao IF EXISTS;
drop VIEW PoliticaNacionalAIDS if exists;
DROP VIEW Paisesss IF EXISTS;

CREATE VIEW Paisesss AS
SELECT Pr."National condom strategy/plan" AS "Tem uma política ou estratégio nacional de distribuição de camisinhas?", Pa.regiao, Pa.classificacaoRenda FROM Prevencao Pr, Pais Pa WHERE Pr.country = Pa.nome AND Pr."National condom strategy/plan" <> '';  
SELECT Pr."National condom strategy/plan", COUNT(*) "Contagem" FROM Prevencao Pr GROUP BY Pr."National condom strategy/plan" LIMIT 2;

DROP VIEW PaisesPorRegiao IF EXISTS;
CREATE VIEW PaisesPorRegiao AS (SELECT regiao, COUNT(*) "Quantidade de paises" FROM Pais GROUP BY Regiao);


CREATE VIEW AgrupadoPorRegiao AS SELECT regiao, "Tem uma política ou estratégio nacional de distribuição de camisinhas?",  COUNT(*) Quantidade FROM Paisesss GROUP BY "Tem uma política ou estratégio nacional de distribuição de camisinhas?", regiao ORDER BY regiao;

SELECT * FROM PaisesPorRegiao;

SELECT * FROM AgrupadoPorRegiao;


CREATE VIEW PoliticaNacionalAIDS AS SELECT regiao, "National strategy/policy guiding AIDS response",  COUNT(*) Quantidade FROM (SELECT Pr."National strategy/policy guiding AIDS response" AS "National strategy/policy guiding AIDS response", Pa.regiao, Pa.classificacaoRenda FROM Legislacao Pr, Pais Pa WHERE Pr.country = Pa.nome AND Pr."National strategy/policy guiding AIDS response" <> '') GROUP BY "National strategy/policy guiding AIDS response", regiao ORDER BY regiao;
select * from PoliticaNacionalAIDS;

SELECT classificacaoRenda, "Possible to start ART on the same day as HIV diagnosis",  COUNT(*) Quantidade FROM (SELECT Pr."Possible to start ART on the same day as HIV diagnosis" AS "Possible to start ART on the same day as HIV diagnosis", Pa.classificacaoRenda  FROM Legislacao Pr, Pais Pa WHERE Pr.country = Pa.nome AND Pr."Possible to start ART on the same day as HIV diagnosis" <> '') GROUP BY "Possible to start ART on the same day as HIV diagnosis", classificacaoRenda ORDER BY classificacaoRenda;
